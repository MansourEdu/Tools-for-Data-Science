# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Created by: Mansour Alatiyah**

# %% [markdown]
# _I am interested in data science because it is a new field in IT and it looks promising. Also, to keep the mind ticking._

# %% [markdown]
# ### This code well print the hello world sentence

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# *  There are four weeks in the Tools for Data Science course:
#
#     1.Data Scientist's Toolkit
#
#     2.Open Source Tools
#
#     3.IBM Tools for Data Science
#
#     4.Final Assignment: Create and Share Your Jupyter Notebook
#
# * For information:
#      (https://www.coursera.org/)
#
#
#      ![اعمال إنشائية.PNG](attachment:56469635-5e8a-4f94-a9ba-624d98337fdc.PNG)
